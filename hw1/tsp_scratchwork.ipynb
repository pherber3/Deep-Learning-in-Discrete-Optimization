# %%
import pandas as pd

# %%
data = pd.read_csv('usa50.txt', error_bad_lines=False)
data.columns = ["Distances"]
data.style
# Out:
# <style  type="text/css" >
# </style><table id="T_69cc9466_52a4_11ea_a0fe_acbc32cf6733" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Distances</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_69cc9466_52a4_11ea_a0fe_acbc32cf6733level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_69cc9466_52a4_11ea_a0fe_acbc32cf6733row0_col0" class="data row0 col0" > 2615331        0 </td>
#             </tr>
#             <tr>
#                         <th id="T_69cc9466_52a4_11ea_a0fe_acbc32cf6733level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_69cc9466_52a4_11ea_a0fe_acbc32cf6733row1_col0" class="data row1 col0" >  703118  2072393        0 </td>
#             </tr>
#             <tr>
#                         <th id="T_69cc9466_52a4_11ea_a0fe_acbc32cf6733level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
data = data.Distances.str.split(expand=True)
data.index += 1
n = data.columns.stop
data.style
# Out:
# <style  type="text/css" >
# ...

# %%
dist = {(i, j):
        int(data.loc[i][j])
        for i in range(n) for j in range(i)}

# %%
dist
# Out:
# {(1, 0): 2615331,
#  (2, 0): 703118,
#  (2, 1): 2072393,
#  (3, 0): 3676539,
#  (3, 1): 1082921,
#  (3, 2): 3004953,
#  (4, 0): 3851355,
#  (4, 1): 1257737,
#  (4, 2): 3179769,
#  (4, 3): 212841,
#  (5, 0): 2157569,
#  (5, 1): 973994,
#  (5, 2): 1600474,
#  (5, 3): 2028101,
#  (5, 4): 2110257,
#  (6, 0): 2109747,
#  (6, 1): 4039492,
#  (6, 2): 2177479,
#  (6, 3): 4976755,
#  (6, 4): 4838236,
#  (6, 5): 3109610,
#  (7, 0): 1707247,
#  (7, 1): 3741677,
#  (7, 2): 1783543,
#  (7, 3): 4676829,
#  (7, 4): 4651287,
#  (7, 5): 2811795,
#  (7, 6): 484719,
#  (8, 0): 1557762,
#  (8, 1): 3663661,
#  (8, 2): 1627313,
#  (8, 3): 4598813,
#  (8, 4): 4524629,
#  (8, 5): 2685136,
#  (8, 6): 551239,
#  (8, 7): 145742,
#  (9, 0): 880086,
#  (9, 1): 3497485,
#  (9, 2): 1567778,
#  (9, 3): 4432637,
#  (9, 4): 4607140,
#  (9, 5): 3065349,
#  (9, 6): 1947381,
#  (9, 7): 1544583,
#  (9, 8): 1394370,
#  (10, 0): 625397,
#  (10, 1): 3274814,
#  (10, 2): 1238466,
#  (10, 3): 4209966,
#  (10, 4): 4384469,
# ...
